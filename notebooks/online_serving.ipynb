# %%
import json

import pandas as pd
import requests

# %%
new_data = pd.read_csv("../data/house_rent_new.csv")
actual = new_data[["id", "rent"]].set_index("id")["rent"].to_dict()

# %%
new_data = new_data.set_index("id").drop(["rent"], axis=1)

# %%
new_data
# Out:
#      bhk   rent  size            floor    area_type       city  \
# 0      2  17000  1000  Ground out of 2   Super Area    Chennai
# 1      2  15000   980       1 out of 4   Super Area    Chennai
# 2      2  18000   900       3 out of 4  Carpet Area      Delhi
# 3      3  80000  1050     16 out of 31  Carpet Area     Mumbai
# 4      3  12500  1250       2 out of 5  Carpet Area  Hyderabad
# ..   ...    ...   ...              ...          ...        ...
# 972    1  15000   550      9 out of 15  Carpet Area    Chennai
# 973    3  95000  2700     23 out of 30  Carpet Area  Hyderabad
# 974    3  50000  2300       2 out of 5  Carpet Area  Hyderabad
# 975    3  67000  2310      3 out of 17   Super Area  Hyderabad
# 976    3  15000  1200       2 out of 5  Carpet Area    Chennai
#
#     furnishing_status  tenant_preferred  bathroom point_of_contact        id
# 0         Unfurnished  Bachelors/Family         2    Contact Owner  104bbcc1
# ...

# %%
for i, row in new_data[:1000].iterrows():
    response = requests.post(
        "http://127.0.0.1:3000/predict", data=json.dumps(row.to_dict())
    )
    prediction = response.json()[0]
    response.close()

    print(
        f"Prediction for User {i}: {prediction:.2f}\t"
        f"Actual value: {actual.get(i, 0)}"
    )
# Out:
# Prediction for User 0: 12731.74	Actual value: 0
# Prediction for User 1: 12831.12	Actual value: 0
# Prediction for User 2: 12973.27	Actual value: 0
# Prediction for User 3: 93168.71	Actual value: 0
# Prediction for User 4: 17092.10	Actual value: 0
# Prediction for User 5: 13476.83	Actual value: 0
# Prediction for User 6: 63836.73	Actual value: 0
# Prediction for User 7: 5139.49	Actual value: 0
# Prediction for User 8: 22395.24	Actual value: 0
# Prediction for User 9: 57035.70	Actual value: 0
# Prediction for User 10: 24256.29	Actual value: 0
# Prediction for User 11: 37022.75	Actual value: 0
# Prediction for User 12: 13880.37	Actual value: 0
# Prediction for User 13: 15611.25	Actual value: 0
# Prediction for User 14: 8099.20	Actual value: 0
# Prediction for User 15: 14103.86	Actual value: 0
# Prediction for User 16: 12386.07	Actual value: 0
# Prediction for User 17: 6413.08	Actual value: 0
# Prediction for User 18: 61892.94	Actual value: 0
# ...
